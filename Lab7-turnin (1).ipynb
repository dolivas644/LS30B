# %%
# Name:Diana Olivas
# I worked on this code with:

# Please do all of your work for this week's lab in this worksheet. If
# you wish to create other worksheets for scratch work, you can, but
# this is the one that will be graded. You do not need to do anything
# to turn in your lab. It will be collected by your TA at the beginning
# of (or right before) next week’s lab.

# Be sure to clearly label which question you are answering as you go and to
# use enough comments that you and the grader can understand your code.

# %%
#Exercise 32
type(matrix)
# Out:
# <class 'cython_function_or_method'>

# %%
#Exercise 33
M=matrix(RDF,[[0.57,0.5025],[0.33,0.917]])
M
# Out:
# [  0.57 0.5025]
# [  0.33  0.917]

# %%
M.eigenvectors_right()
# Out:
# [(0.3008632979519208, [(-0.8815235799988788, 0.4721399982059986)], 1),
#  (1.186136702048079, [(-0.6320226312996823, -0.7749499296890257)], 1)]

# %%
M=matrix((RDF),[[0.57, 0.5025],[0.33,0.917]])
M
E= M.eigenvectors_right()
E
E[0][1][0]
E[1][1][0]
# Out:
# (-0.6320226312996823, -0.7749499296890257)

# %%
plot1=vector([-0.882,0.472])
plot2=vector([-0.632,-0.775])
plot(plot1,aspect_ratio=1,color="blue")+plot(plot2,aspect_ratio=1,color="green")
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Exercise 34
multvector1=M*plot1

# %%
multvector2=M*plot2

# %%
plot(plot1, color="blue") + plot(multvector2, color="red") + plot(plot2, color="green") + plot(multvector1, color="orange")
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
#the first eigenvector, aqua, became shorter in length(orange)
#the second eigenvector(green) became longer in length(red)

# %%
#Exercise 35
plot1.norm()
# Out:
# 1.00035393736417

# %%
plot2.norm()
# Out:
# 1.00002449969988

# %%
multvector1.norm()
# Out:
# 0.30103014017868707

# %%
multvector2.norm()
# Out:
# 1.1861742448861592

# %%
multvector1.norm()/plot1.norm()
# Out:
# 0.30092363206153844

# %%
#Exercise 36
E[1][0][0]
# Out:
# 1.186136702048079

# %%
E[0][0][0]
# Out:
# 0.3008632979519208

# %%
#Exercise 37
L=matrix([[0,0,35315], [0.00003, 0.777, 0], [0, 0.071, 0.949]])

# %%
#adults to larvae
35315
# Out:
# 35315

# %%
#adults to adults
0.949
# Out:
# 0.949000000000000

# %%
#larvae to juveniles
0.00003
# Out:
# 0.0000300000000000000

# %%
#juveniles to juveniles
0.777
# Out:
# 0.777000000000000

# %%
#Exercise 38
L
# Out:
# [    0.000000000000000     0.000000000000000      35315.0000000000]
# [0.0000300000000000000     0.777000000000000     0.000000000000000]
# [    0.000000000000000    0.0710000000000000     0.949000000000000]

# %%
#Exercise 39
lion=matrix(RDF, [[0,0,35315], [0.00003, 0.777, 0], [0, 0.071, 0.949]])
R=lion.eigenvectors_right()
R
# Out:
# [(0.15026156162015658,
#   [(0.9999999988453299, -4.78668582110772e-05, 4.254893429043022e-06)],
#   1),
#  (0.44126018150798385,
#   [(-0.9999999959297882, 8.935490586919178e-05, -1.2494978895992127e-05)],
#   1),
#  (1.1344782568718599,
#   [(0.999999995962624, 8.392118765878533e-05, 3.212454346004658e-05)],
#   1)]

# %%
#Long-term growth rate of the lionfish population is the largest eigenvalue
1.1344782568718599
# Out:
# 1.134478256871860

# %%
#Long-term population proportions will be the eigenvector corresponding to the dominant eigenvalue (L, J, A)
[(0.999999995962624, 8.392118765878533e-05, 3.212454346004658e-05)]
# Out:
# [(0.999999995962624, 0.0000839211876587853, 0.0000321245434600466)]

# %%
lion=matrix(RDF, [[0,0,35315], [0.00003, 0.777, 0], [0, 0.071, 0.949]])
R=lion.eigenvectors_right()
R
1.1344782568718599
[(0.999999995962624, 8.392118765878533e-05, 3.212454346004658e-05)]
# Out:
# [(0.999999995962624, 0.0000839211876587853, 0.0000321245434600466)]

# %%
#Exercise 40
v=vector([3,4,5])
for i in srange(50):
    v=L*v
v
v1=vector([11,34,52])
for i in srange(50):
    v1=L*v1
v1
# Out:
# (5.97154210340885e8, 50113.8907495796, 19183.3064598958)

# %%
#Exercise 41
#The dom eigenvalue has to be 1 in order to be constant & the absolute value of the dom eigenvalue has to be <1 in order to be declining.

# %%
#Exercise 42
lion=matrix(RDF, [[0,0,35315], [0.00003, 0.777, 0], [0, 0.0000000003, 0.949]])
R=lion.eigenvectors_right()
R
# Out:
# [(4.310369838833594e-10,
#   [(0.9999999992546326, -3.8610038602678676e-05, 1.2205491660763567e-14)],
#   1),
#  (0.7769999976217786,
#   [(-7.927404687950248e-05, 0.9999999968578128, -1.744186016914439e-09)],
#   1),
#  (0.9490000019471843,
#   [(0.999999984428012, 0.00017441859996055362, 2.6872433446676147e-05)],
#   1)]

# %%
lion=matrix(RDF, [[0,0,5500], [0.00003, 0.777, 0], [0, 0.071, 0.949]])
R=lion.eigenvectors_right()
R
# Out:
# [(0.016520195122644465,
#   [(0.9999999992173858, -3.94487792892275e-05, 3.003671838130085e-06)],
#   1),
#  (0.7082877233641607,
#   [(-0.9999998963967471, 0.0004366031568259051, -0.0001287795727242268)],
#   1),
#  (1.0011920815131947,
#   [(0.9999999744785744, 0.0001338138217544119, 0.00018203491926569923)],
#   1)]

# %%
lion=matrix(RDF, [[0,0,35315], [0.00003, 0.65, 0], [0, 0.071, 0.949]])
R=lion.eigenvectors_right()
R
# Out:
# [(0.24917407793237076 + 0.07908515734712433*I,
#   [(-0.9999999972766319, 7.20409435662786e-05 + 1.4214074099761357e-05*I, -7.055757532317094e-06 - 2.2394211278988063e-06*I)],
#   1),
#  (0.24917407793237076 - 0.07908515734712433*I,
#   [(-0.9999999972766319, 7.20409435662786e-05 - 1.4214074099761357e-05*I, -7.055757532317094e-06 + 2.2394211278988063e-06*I)],
#   1),
#  (1.1006518441352577,
#   [(0.9999999972985204, 6.65702366680018e-05, 3.116669520492339e-05)],
#   1)]

# %%
#Thw biggest reduction in growth rate was given by reducing the larvae by reducing the number of adults that become larvae which allowed me to get an eigenvalue closest to 1 without becoming less than 1(was decaying).

#Despite becoming very small, when reducing the number of juveniles that became adults the growth rate did not reduce.

# %%
#Exercise 43
@interact
def interactive(d1=(-10, 10, .1), d2=(-10, 10, .1), target=vector([2,3])):
    u=vector([1, 2])
    v=vector([1, 0.5])
    p= d1*u + d2*v
    p1=plot(p, aspect_ratio=1, color="red") + plot(target, aspect_ratio=1, color="blue") + plot(u, aspect_ratio=1, color="green") + plot(v, aspect_ratio=1, color="yellow")
    show(p1)
# Out:
# Interactive function <function interactive at 0x7fa5596ae280> with 3 widgets
#   d1: FloatSlider(value=0.0, desc…

# %%
@interact
def interactive(d1=(-10, 10, .1), d2=(-10, 10, .1), target=vector([-5,1.2])):
    u=vector([1, 2])
    v=vector([1, 0.5])
    p= d1*u + d2*v
    p1=plot(p, aspect_ratio=1, color="red") + plot(target, aspect_ratio=1, color="blue") + plot(u, aspect_ratio=1, color="green") + plot(v, aspect_ratio=1, color="yellow")
    show(p1)
# Out:
# Interactive function <function interactive at 0x7fa781523550> with 3 widgets
#   d1: FloatSlider(value=0.0, desc…

# %%
@interact
def interactive(d1=(-10, 10, .1), d2=(-10, 10, .1), target=vector([-4,-8])):
    u=vector([1, 2])
    v=vector([1, 0.5])
    p= d1*u + d2*v
    p1=plot(p, aspect_ratio=1, color="red") + plot(target, aspect_ratio=1, color="blue") + plot(u, aspect_ratio=1, color="green") + plot(v, aspect_ratio=1, color="yellow")
    show(p1)
# Out:
# Interactive function <function interactive at 0x7fa559528ee0> with 3 widgets
#   d1: FloatSlider(value=0.0, desc…

# %%
@interact
def interactive(d1=(-10, 10, .1), d2=(-10, 10, .1), target=vector([3,-2.4])):
    u=vector([1, 2])
    v=vector([1, 0.5])
    p= d1*u + d2*v
    p1=plot(p, aspect_ratio=1, color="red") + plot(target, aspect_ratio=1, color="blue") + plot(u, aspect_ratio=1, color="green") + plot(v, aspect_ratio=1, color="yellow")
    show(p1)
# Out:
# Interactive function <function interactive at 0x7fa5596173a0> with 3 widgets
#   d1: FloatSlider(value=0.0, desc…

# %%
#Exercise 44
@interact
def interactive(d1=(-10, 10, .1), d2=(-10, 10, .1), target=vector([2,3])):
    u=vector([1, 0.5])
    v=vector([1, 2])
    p= d1*u + d2*v
    p1=plot(p, aspect_ratio=1, color="red") + plot(target, aspect_ratio=1, color="blue") + plot(u, aspect_ratio=1, color="green") + plot(v, aspect_ratio=1, color="yellow")
    show(p1)
# Out:
# Interactive function <function interactive at 0x7fa55945a670> with 3 widgets
#   d1: FloatSlider(value=0.0, desc…

# %%
@interact
def interactive(d1=(-10, 10, .1), d2=(-10, 10, .1), target=vector([-5,1.2])):
    u=vector([1, 0.5])
    v=vector([1, 2])
    p= d1*u + d2*v
    p1=plot(p, aspect_ratio=1, color="red") + plot(target, aspect_ratio=1, color="blue") + plot(u, aspect_ratio=1, color="green") + plot(v, aspect_ratio=1, color="yellow")
    show(p1)
# Out:
# Interactive function <function interactive at 0x7fa5593ab310> with 3 widgets
#   d1: FloatSlider(value=0.0, desc…

# %%
@interact
def interactive(d1=(-10, 10, .1), d2=(-10, 10, .1), target=vector([-4,-8])):
    u=vector([1, 0.5])
    v=vector([1, 2])
    p= d1*u + d2*v
    p1=plot(p, aspect_ratio=1, color="red") + plot(target, aspect_ratio=1, color="blue") + plot(u, aspect_ratio=1, color="green") + plot(v, aspect_ratio=1, color="yellow")
    show(p1)
# Out:
# Interactive function <function interactive at 0x7fa5595284c0> with 3 widgets
#   d1: FloatSlider(value=0.0, desc…

# %%
@interact
def interactive(d1=(-10, 10, .1), d2=(-10, 10, .1), target=vector([3,-2.4])):
    u=vector([1, 0.5])
    v=vector([1, 2])
    p= d1*u + d2*v
    p1=plot(p, aspect_ratio=1, color="red") + plot(target, aspect_ratio=1, color="blue") + plot(u, aspect_ratio=1, color="green") + plot(v, aspect_ratio=1, color="yellow")
    show(p1)
# Out:
# Interactive function <function interactive at 0x7fa55975ce50> with 3 widgets
#   d1: FloatSlider(value=0.0, desc…

# %%
#Exercise 45
@interact
def interactive(d1=(-10, 10, .1), d2=(-10, 10, .1), target=vector([3,-2.4])):
    u=vector([1, 2])
    v=vector([2, 4])
    p= d1*u + d2*v
    p1=plot(p, aspect_ratio=1, color="red") + plot(target, aspect_ratio=1, color="blue") + plot(u, aspect_ratio=1, color="green") + plot(v, aspect_ratio=1, color="yellow")
    show(p1)
# Out:
# Interactive function <function interactive at 0x7fa559411820> with 3 widgets
#   d1: FloatSlider(value=0.0, desc…
